# %% [markdown]
# ### 課程內容
#
# - 教broadcast / 迴圈製圖
#
# - 先將 num 存成變數再帶進scipt.stats() 的重要性
#
# - 將虛擬環境( 包含套件( 有指定版本 ) ) 複製  pip freeze - requirements  ( freeze 傳出指定版本 )
#
# - 接著用pip install -r requirements.txt ( 下載別人的虛擬環境 )

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import norm 

loc=

x=np.linspace(-5,5,200)
y=norm.cdf(x,10,1)

plt.plot(x,y)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

from scipy.stats import norm 

fig,axes=plt.subplots(2,1,igsize=(15,10))

x=np.linspace(-5,5,200)
loc=np.array([1,3,5,7])
y=norm.pdf(x.reshape(-1,1),loc)

for i in loc :
    plt.plot(x,norm.pdf(x.reshape(-1,1),i))

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import chi2 

x=np.linspace(0,100,100)
std=1
loc=np.arange(4,100,4)
y=chi2.pdf(x.reshape(-1,1),loc,scale=std)


plt.plot(x,y)
plt.gca().set_xlim([0,100])
# Out:
# (0.0, 100.0)

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt
 
n, p = 20, 0.7
x = np.arange(n + 1)
y = binom.pmf(x, n, p)
fig, ax = plt.subplots(4,1, sharex = 'col', figsize = [6, 9])
ax[0].stem(x, y, linefmt='k-', markerfmt='ko', basefmt = 'C2--')
ax[1].bar(x, y, width = 0.9, color = 'r', edgecolor = 'y' )
ax[2].vlines(x, 0, y, lw = 5, alpha = 0.5)
Y = binom.cdf(x, n, p)
ax[3].plot(x, Y, drawstyle = 'steps-pre')
plt.suptitle('The PMF and CDF of Bino({}, {})'.format(n, p))
plt.show()
